# %%
import torch

x = torch.tensor([1, 2, 3])

print(x)
# Out:
# tensor([1, 2, 3])

# %%
print(x.shape)
print(x.dtype)
print(x.device)
# Out:
# torch.Size([3])
# torch.int64
# cpu

# %%
print(x[0])
print(x[1])
print(x[2])
# Out:
# tensor(1)
# tensor(2)
# tensor(3)

# %%
y = torch.tensor([[1, 2],
                 [3, 4]])
print(y)
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
print(y.shape)
# Out:
# torch.Size([2, 2])
